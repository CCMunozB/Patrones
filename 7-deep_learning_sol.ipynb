# %% [markdown]
# <a href="https://colab.research.google.com/github/CCMunozB/Patrones/blob/main/7-deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning: Segmentación de imágenes

# %% [markdown]
# Deep learning es un tipo de aprendizaje de máquinas en donde las predicciones se realizan a través de una serie de operaciones matriciales concatenadas. Uno de los elementos más importantes en el Deep Learning es la casi nula ingeniería de características. En el ejemplo que veremos ahora, se utiliza un conjunto de imágenes segmentadas para realizar el entrenamiento de un modelo de segmentación automática de núcleos celulares, este entrenamiento simplemente se realiza con los pixeles crudos de las imágenes, sin ingeniería de características.

# %%
# Importamos todos los paquetes y módulos para entrenar el modelo

import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras import layers
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers import concatenate
from keras.utils import image_dataset_from_directory
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# %% [markdown]
# Google Colab nos ofrece poder utilizar GPUs (Graphical Processing Units) para realizar el entrenamiento. La utilización de este hardware nos facilita un entrenamiento muy significativamente más rápido que el entrenamiento en CPU.

# %%
tf.test.gpu_device_name() # Verificamos que Tensorflow está utilizando una GPU
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Clasificación Inception V3

# %%
#Descargamos la Base de Datos, una versión mini de ImageNet 
# !gdown 1aNRd1WZT7s4vIXy3mGgLsMQI1N9B6qrc -O cats.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1aNRd1WZT7s4vIXy3mGgLsMQI1N9B6qrc
# To: /content/cats.zip
# 100% 129M/129M [00:03<00:00, 42.2MB/s]

# %%
#Unzip BD
# !unzip -q cats.zip -d cats/

# %%
from tensorflow.keras.applications import InceptionV3

#Base Model
pre_trained_model = InceptionV3(
    input_shape=(299, 299, 3), include_top=True, weights="imagenet")

#Base model por transfer
pre_trained_model_transfer = InceptionV3(
    input_shape=(224, 224, 3), include_top=False, weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 6s 0us/step

# %%
#Flatten a una capa de 1 dimensión
x = layers.Flatten()(pre_trained_model_transfer.output)
#Se añade una capa Fully-Connected
x = layers.Dense(1024, activation="relu")(x)
#Se añade una capa de Dropout
x = layers.Dropout(0.2)(x)
#Capa final de clasificación
x = layers.Dense(10, activation="softmax")(x)

model = Model(pre_trained_model_transfer.input, x)

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from PIL import Image

img_size = (224, 224)

def plot_images(folder):
    subfolders = [f.path for f in os.scandir(folder) if f.is_dir()]
    fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(12, 6))
    for i, subfolder in enumerate(subfolders):
        filenames = os.listdir(subfolder)
        image_path = os.path.join(subfolder, filenames[4])
        image = Image.open(image_path)
        imgae = image.resize(img_size)
        ax = axes[i // 5, i % 5]
        ax.imshow(image)
        ax.set_title(os.path.basename(subfolder))
        ax.axis("off")

plot_images("/content/cats/train")

# %%
#Cargar Cats
#Data Augmentation 
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255) # A las imágenes se les normaliza el brillo

train_datagen_aug = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                                shear_range = 0.2, # Distorsionamos las imágenes
                                                                zoom_range = 0.2, # Acercamos las imágenes
                                                                horizontal_flip = True,
                                                                vertical_flip=True) # Volteamos horizontalmente las imágenes

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)                                  

#Entrenamiento
train_cat = train_datagen.flow_from_directory('/content/cats/train',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Entrenamiento Data Augmentation
train_cat_aug = train_datagen_aug.flow_from_directory('/content/cats/train',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Validación
val_cat = test_datagen.flow_from_directory('/content/cats/valid',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Test
test_cat = test_datagen.flow_from_directory('/content/cats/test',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')
# Out:
# Found 2339 images belonging to 10 classes.
# Found 2339 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.

# %%
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
def get_callbacks():
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1)
    checkpoint = ModelCheckpoint('cats.hdf5',verbose=1, save_best_only= True)
    early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
    return [reduce_lr, checkpoint, early_stop]

#hist = model.fit(train_cat,
#          epochs = 30,
#          validation_data = val_cat,
#          callbacks=get_callbacks())

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.ylim([0,1])
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Actividad 1
#
# Entrene nuevamente el modelo Inception V3 utilizando aumento de datos y compruebe la diferencia en el entrenamiento.

# %%
hist = model.fit(train_cat_aug,
         epochs = 30,
         validation_data = val_cat,
         callbacks=get_callbacks())
# Out:
# Epoch 1/30
# 147/147 [==============================] - ETA: 0s - loss: 0.6094 - accuracy: 0.1159
# Epoch 1: val_loss improved from inf to 0.36734, saving model to cats.hdf5
# 147/147 [==============================] - 63s 199ms/step - loss: 0.6094 - accuracy: 0.1159 - val_loss: 0.3673 - val_accuracy: 0.0600 - lr: 0.0010
# Epoch 2/30
# 147/147 [==============================] - ETA: 0s - loss: 0.3049 - accuracy: 0.2227
# Epoch 2: val_loss improved from 0.36734 to 0.25421, saving model to cats.hdf5
# 147/147 [==============================] - 28s 188ms/step - loss: 0.3049 - accuracy: 0.2227 - val_loss: 0.2542 - val_accuracy: 0.3600 - lr: 0.0010
# Epoch 3/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.3087
# Epoch 3: val_loss improved from 0.25421 to 0.25236, saving model to cats.hdf5
# 147/147 [==============================] - 28s 187ms/step - loss: 0.2635 - accuracy: 0.3087 - val_loss: 0.2524 - val_accuracy: 0.2800 - lr: 0.0010
# Epoch 4/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.3634
# Epoch 4: val_loss did not improve from 0.25236
# 147/147 [==============================] - 25s 171ms/step - loss: 0.2471 - accuracy: 0.3634 - val_loss: 0.2680 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 5/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2234 - accuracy: 0.4275
# Epoch 5: val_loss improved from 0.25236 to 0.19919, saving model to cats.hdf5
# 147/147 [==============================] - 28s 189ms/step - loss: 0.2234 - accuracy: 0.4275 - val_loss: 0.1992 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 6/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.4724
# Epoch 6: val_loss did not improve from 0.19919
# 147/147 [==============================] - 25s 173ms/step - loss: 0.2183 - accuracy: 0.4724 - val_loss: 0.9211 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 7/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.4694
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 7: val_loss did not improve from 0.19919
# 147/147 [==============================] - 25s 171ms/step - loss: 0.2221 - accuracy: 0.4694 - val_loss: 0.3816 - val_accuracy: 0.2800 - lr: 0.0010
# Epoch 8/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.5417
# Epoch 8: val_loss improved from 0.19919 to 0.17862, saving model to cats.hdf5
# 147/147 [==============================] - 28s 190ms/step - loss: 0.1963 - accuracy: 0.5417 - val_loss: 0.1786 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 9/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.5442
# Epoch 9: val_loss improved from 0.17862 to 0.16205, saving model to cats.hdf5
# 147/147 [==============================] - 28s 188ms/step - loss: 0.1892 - accuracy: 0.5442 - val_loss: 0.1620 - val_accuracy: 0.6600 - lr: 1.0000e-04
# Epoch 10/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.6109
# Epoch 10: val_loss improved from 0.16205 to 0.14799, saving model to cats.hdf5
# 147/147 [==============================] - 28s 188ms/step - loss: 0.1670 - accuracy: 0.6109 - val_loss: 0.1480 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 11/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.6216
# Epoch 11: val_loss did not improve from 0.14799
# 147/147 [==============================] - 25s 171ms/step - loss: 0.1626 - accuracy: 0.6216 - val_loss: 0.1625 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 12/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.6409
# Epoch 12: val_loss improved from 0.14799 to 0.13799, saving model to cats.hdf5
# 147/147 [==============================] - 27s 186ms/step - loss: 0.1562 - accuracy: 0.6409 - val_loss: 0.1380 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 13/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.6614
# Epoch 13: val_loss did not improve from 0.13799
# 147/147 [==============================] - 25s 172ms/step - loss: 0.1486 - accuracy: 0.6614 - val_loss: 0.1963 - val_accuracy: 0.5200 - lr: 1.0000e-04
# Epoch 14/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.6935
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 14: val_loss did not improve from 0.13799
# 147/147 [==============================] - 25s 171ms/step - loss: 0.1362 - accuracy: 0.6935 - val_loss: 0.1500 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 15/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.7020
# Epoch 15: val_loss did not improve from 0.13799
# 147/147 [==============================] - 25s 171ms/step - loss: 0.1327 - accuracy: 0.7020 - val_loss: 0.1570 - val_accuracy: 0.6600 - lr: 1.0000e-05
# Epoch 16/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.7204
# Epoch 16: val_loss improved from 0.13799 to 0.13540, saving model to cats.hdf5
# 147/147 [==============================] - 28s 189ms/step - loss: 0.1265 - accuracy: 0.7204 - val_loss: 0.1354 - val_accuracy: 0.7000 - lr: 1.0000e-05
# Epoch 17/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.7302
# Epoch 17: val_loss did not improve from 0.13540
# 147/147 [==============================] - 25s 171ms/step - loss: 0.1240 - accuracy: 0.7302 - val_loss: 0.1411 - val_accuracy: 0.7000 - lr: 1.0000e-05
# Epoch 18/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.7435
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 18: val_loss did not improve from 0.13540
# 147/147 [==============================] - 25s 171ms/step - loss: 0.1207 - accuracy: 0.7435 - val_loss: 0.1362 - val_accuracy: 0.6600 - lr: 1.0000e-05
# Epoch 19/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.7298
# Epoch 19: val_loss improved from 0.13540 to 0.13337, saving model to cats.hdf5
# 147/147 [==============================] - 28s 188ms/step - loss: 0.1246 - accuracy: 0.7298 - val_loss: 0.1334 - val_accuracy: 0.7000 - lr: 1.0000e-06
# Epoch 20/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.7212
# Epoch 20: val_loss improved from 0.13337 to 0.13041, saving model to cats.hdf5
# 147/147 [==============================] - 28s 187ms/step - loss: 0.1253 - accuracy: 0.7212 - val_loss: 0.1304 - val_accuracy: 0.7000 - lr: 1.0000e-06
# Epoch 21/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.7448
# Epoch 21: val_loss did not improve from 0.13041
# 147/147 [==============================] - 25s 172ms/step - loss: 0.1230 - accuracy: 0.7448 - val_loss: 0.1311 - val_accuracy: 0.7000 - lr: 1.0000e-06
# Epoch 22/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.7422
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 22: val_loss did not improve from 0.13041
# 147/147 [==============================] - 25s 171ms/step - loss: 0.1214 - accuracy: 0.7422 - val_loss: 0.1313 - val_accuracy: 0.7000 - lr: 1.0000e-06
# Epoch 23/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.7422
# Epoch 23: val_loss improved from 0.13041 to 0.13004, saving model to cats.hdf5
# 147/147 [==============================] - 28s 188ms/step - loss: 0.1236 - accuracy: 0.7422 - val_loss: 0.1300 - val_accuracy: 0.7000 - lr: 1.0000e-07
# Epoch 24/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.7401
# Epoch 24: val_loss did not improve from 0.13004
# 147/147 [==============================] - 25s 172ms/step - loss: 0.1259 - accuracy: 0.7401 - val_loss: 0.1321 - val_accuracy: 0.7000 - lr: 1.0000e-07
# Epoch 25/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.7366
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 25: val_loss did not improve from 0.13004
# 147/147 [==============================] - 25s 170ms/step - loss: 0.1214 - accuracy: 0.7366 - val_loss: 0.1308 - val_accuracy: 0.7000 - lr: 1.0000e-07
# Epoch 26/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1242 - accuracy: 0.7388
# Epoch 26: val_loss did not improve from 0.13004
# 147/147 [==============================] - 25s 172ms/step - loss: 0.1242 - accuracy: 0.7388 - val_loss: 0.1316 - val_accuracy: 0.7000 - lr: 1.0000e-08
# Epoch 27/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.7460
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 27: val_loss did not improve from 0.13004
# 147/147 [==============================] - 25s 171ms/step - loss: 0.1213 - accuracy: 0.7460 - val_loss: 0.1343 - val_accuracy: 0.7000 - lr: 1.0000e-08
# Epoch 28/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.7379
# Epoch 28: val_loss did not improve from 0.13004
# Restoring model weights from the end of the best epoch: 23.
# 147/147 [==============================] - 25s 173ms/step - loss: 0.1247 - accuracy: 0.7379 - val_loss: 0.1311 - val_accuracy: 0.7000 - lr: 1.0000e-09
# Epoch 28: early stopping

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.ylim([0,1])
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Observemos las imágenes con Data Augmentation

plt.figure(figsize=(10,8))
batch = train_cat_aug.next()
#Plots our figures
for i in range(1,17):
  plt.subplot(4, 4, i)
  image_ = batch[0][i-1,:,:,:]
  plt.imshow(image_)
plt.show()

# %% [markdown]
# ## Segmentación con U-Net

# %%
# Obtenemos el conjunto de datos de entrenamiento y prueba
# !gdown 1M2dru41aniQR3fKXrNxd3cXfYd6J1Lvl -O stage1_test.zip
# !gdown 1O7ZZvA2Co8PCi3XnLV71n0GUWx-5MmvR -O stage1_train.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M2dru41aniQR3fKXrNxd3cXfYd6J1Lvl
# To: /content/stage1_test.zip
# 100% 9.55M/9.55M [00:00<00:00, 20.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1O7ZZvA2Co8PCi3XnLV71n0GUWx-5MmvR
# To: /content/stage1_train.zip
# 100% 82.9M/82.9M [00:01<00:00, 43.8MB/s]

# %%
# Descomprimimos los conjuntos de datos.
# !unzip -q stage1_train.zip -d stage1_train/
# !unzip -q stage1_test.zip -d stage1_test/

# %%
IMG_WIDTH = 128 # Ancho en el que se redimensionarán las imágenes.
IMG_HEIGHT = 128 # Alto en el que se redimensionarán las imágenes.
IMG_CHANNELS = 3 # Canales de color que tienen las imágenes (rojo, verde y azul)
TRAIN_PATH = 'stage1_train/' # Ubicación del conjunto de datos de entrenamiento.
TEST_PATH = 'stage1_test/' # Ubicación del conjunto de datos de prueba.

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')

# Establecemos una semilla para la generación de datos aleatorios
seed = 11 
random.seed = seed
np.random.seed = seed

# %%
# Obtenemos los nombres de las imágenes de entrenamiento y prueba
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Redimensionamos todas las imágenes
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# <ipython-input-14-38464d2cb465>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|          | 0/670 [00:00<?, ?it/s]<ipython-input-14-38464d2cb465>:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|██████████| 670/670 [04:13<00:00,  2.64it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:01<00:00, 46.03it/s]
# Done!

# %%
# Verificamos la imagen cruda y la máscara de segmentación de una imagen al azar.
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %% [markdown]
# U-Net es una arquitectura especializada para la segmentación de imágenes biomédicas https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/ .
#
# Esta arquitectura utiliza una serie de capas de convolución para realizar las predicciones y el esquema es el siguiente:
#
# ![U-Net Architecture](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
# Esta es la implementación en TensorFlow de U-Net

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s) # Capa convolucional
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.MeanIoU(2)])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 128, 128, 3)  0           ['input_3[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 128, 128, 16  448         ['lambda[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 16  0           ['conv2d_188[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 128, 128, 16  2320        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 16)  0           ['conv2d_189[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 64, 64, 32)   4640        ['max_pooling2d_8[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 64, 64, 32)   9248        ['dropout_2[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 32, 32, 64)   18496       ['max_pooling2d_9[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 32, 32, 64)   36928       ['dropout_3[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_193[0][0]']
#  )
#
#  conv2d_194 (Conv2D)            (None, 16, 16, 128)  73856       ['max_pooling2d_10[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_194[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_4[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 128)   0           ['conv2d_195[0][0]']
#  )
#
#  conv2d_196 (Conv2D)            (None, 8, 8, 256)    295168      ['max_pooling2d_11[0][0]']
#
#  dropout_5 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 8, 8, 256)    590080      ['dropout_5[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['conv2d_197[0][0]']
#  ose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_195[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 16, 16, 128)  295040      ['concatenate_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_198[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_6[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_199[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_193[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 32, 32, 64)   73792       ['concatenate_5[0][0]']
#
#  dropout_7 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 32, 32, 64)   36928       ['dropout_7[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_201[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_191[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 64, 64, 32)   18464       ['concatenate_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_202[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 64, 64, 32)   9248        ['dropout_8[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_203[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_189[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 128, 128, 16  4624        ['concatenate_7[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 128, 128, 16  0           ['conv2d_204[0][0]']
#                                 )
#
#  conv2d_205 (Conv2D)            (None, 128, 128, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  conv2d_206 (Conv2D)            (None, 128, 128, 1)  17          ['conv2d_205[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# La arquitectura cuenta con alrededor de 2 millones de parámetros que serán entrenados.

# %%
# Entrenamiento del modelo

earlystopper = EarlyStopping(patience=5, verbose=1)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper])
# Out:
# Epoch 1/50
# 38/38 [==============================] - 22s 71ms/step - loss: 0.4177 - mean_io_u: 0.3764 - val_loss: 0.2324 - val_mean_io_u: 0.3717
# Epoch 2/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.2070 - mean_io_u: 0.3764 - val_loss: 0.1703 - val_mean_io_u: 0.3717
# Epoch 3/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1623 - mean_io_u: 0.3764 - val_loss: 0.1401 - val_mean_io_u: 0.3717
# Epoch 4/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1448 - mean_io_u: 0.3764 - val_loss: 0.1378 - val_mean_io_u: 0.3717
# Epoch 5/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1319 - mean_io_u: 0.3764 - val_loss: 0.1176 - val_mean_io_u: 0.3717
# Epoch 6/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1233 - mean_io_u: 0.3764 - val_loss: 0.1078 - val_mean_io_u: 0.3717
# Epoch 7/50
# 38/38 [==============================] - 1s 16ms/step - loss: 0.1149 - mean_io_u: 0.3764 - val_loss: 0.1044 - val_mean_io_u: 0.3717
# Epoch 8/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1186 - mean_io_u: 0.3764 - val_loss: 0.1135 - val_mean_io_u: 0.3717
# Epoch 9/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1135 - mean_io_u: 0.3764 - val_loss: 0.1016 - val_mean_io_u: 0.3717
# Epoch 10/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1056 - mean_io_u: 0.3764 - val_loss: 0.1024 - val_mean_io_u: 0.3717
# Epoch 11/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1020 - mean_io_u: 0.3764 - val_loss: 0.1083 - val_mean_io_u: 0.3717
# Epoch 12/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1018 - mean_io_u: 0.3764 - val_loss: 0.0956 - val_mean_io_u: 0.3717
# Epoch 13/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0987 - mean_io_u: 0.3764 - val_loss: 0.1055 - val_mean_io_u: 0.3717
# Epoch 14/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0971 - mean_io_u: 0.3764 - val_loss: 0.0969 - val_mean_io_u: 0.3717
# Epoch 15/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0991 - mean_io_u: 0.3764 - val_loss: 0.0905 - val_mean_io_u: 0.3717
# Epoch 16/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0969 - mean_io_u: 0.3764 - val_loss: 0.0941 - val_mean_io_u: 0.3717
# Epoch 17/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0942 - mean_io_u: 0.3764 - val_loss: 0.0914 - val_mean_io_u: 0.3717
# Epoch 18/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0923 - mean_io_u: 0.3764 - val_loss: 0.0888 - val_mean_io_u: 0.3717
# Epoch 19/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0900 - mean_io_u: 0.3764 - val_loss: 0.0884 - val_mean_io_u: 0.3717
# Epoch 20/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0896 - mean_io_u: 0.3764 - val_loss: 0.0868 - val_mean_io_u: 0.3717
# Epoch 21/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0884 - mean_io_u: 0.3764 - val_loss: 0.0864 - val_mean_io_u: 0.3717
# Epoch 22/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0881 - mean_io_u: 0.3764 - val_loss: 0.0860 - val_mean_io_u: 0.3717
# Epoch 23/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0858 - mean_io_u: 0.3764 - val_loss: 0.0872 - val_mean_io_u: 0.3717
# Epoch 24/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0877 - mean_io_u: 0.3764 - val_loss: 0.0930 - val_mean_io_u: 0.3717
# Epoch 25/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0856 - mean_io_u: 0.3764 - val_loss: 0.0830 - val_mean_io_u: 0.3717
# Epoch 26/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0827 - mean_io_u: 0.3764 - val_loss: 0.0814 - val_mean_io_u: 0.3717
# Epoch 27/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0814 - mean_io_u: 0.3764 - val_loss: 0.0820 - val_mean_io_u: 0.3717
# Epoch 28/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0810 - mean_io_u: 0.3764 - val_loss: 0.0830 - val_mean_io_u: 0.3717
# Epoch 29/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0805 - mean_io_u: 0.3764 - val_loss: 0.0872 - val_mean_io_u: 0.3717
# Epoch 30/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0799 - mean_io_u: 0.3764 - val_loss: 0.0834 - val_mean_io_u: 0.3717
# Epoch 31/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0771 - mean_io_u: 0.3764 - val_loss: 0.0817 - val_mean_io_u: 0.3717
# Epoch 31: early stopping

# %%
# Predicción sobre los datos de entrenamiento, validación y prueba

preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 19/19 [==============================] - 1s 22ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 163ms/step

# %%
# Visualizamos unas predicciones al azar sobre el conjunto de entrenamiento

ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Visualizamos unas predicciones al azar sobre el conjunto de validación

ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()

# %% [markdown]
# ## Actividad 2
#
# Visualiza la salida de alguna de las capas de convolución. Puedes utilizar las funciones de la clase anterior.

# %%
def get_activations(model,img_array):
  # Creamos un modelo que entrega los resultados después de cada capa
  layer_outputs = [layer.output for layer in model.layers]
  layer_names = [layer.name for layer in model.layers]
  activation_model = tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)
  activations = activation_model.predict(img_array)
  activations = list(zip(layer_names,activations))
  return activations
def plot_conv_layer_result(activations,j):
  fig, axs = plt.subplots(
      nrows=2,
      ncols=8,
      figsize=(15,8)
  )
  fig.suptitle(activations[j][0])
  for i,ax in enumerate(axs.ravel()):
      ax.imshow(activations[j][1][0,:,:,i], cmap="viridis")
      ax.axis("off")
  plt.show()

# %%
activations = get_activations(model, X_train[:int(X_train.shape[0]*0.9)])
# Out:
# 19/19 [==============================] - 1s 19ms/step

# %%
plot_conv_layer_result(activations, 8)

# %%
plot_conv_layer_result(activations, 36)
